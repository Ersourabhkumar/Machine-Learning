# %%
# A decesion tree is a supervised ML algorithem that is used for classification and regression
# it looks like a tree structure where root node is the first split and than internal nodes 
# represent the conditions.
# is decesion point and there are branches they represent the out come of the condition and there are leaf nodes these are the final prediction

# How does  a decision tree works
# it works by  spliting the dataset into subset based on the most significant feature
# step(1). choose  the best feature split--> this algorithm  looks all the feature and decides which feature best separate the data it 
# uses mathmatical mojar like:- giniindex and entropy  and information game.

# giniindex:-->it majors impority how much the classes
# lower gini=better split
# entropy and info. game --->this major disorder ya uncertainity the more mixed  classes and higher the Entropy .
# varianse reduction --> when the target is continuous number(data) it chooose a split that makes child nodes have
# less variance in target values.

# step(2).split the dataset--> based on the choosen feature the data is devide it into branches each branch represent a posible outcome of that
# feature.
# step(3).repeat recursively--> for each new subset the algorithm again chooses the best feacture to split and this process continuous 
# until all data points belong to one class or no feactures are left or a maximum that or limit is reached.

# step(4).stoping critaria-->to prevent overfiting trees stop spliting if maximun defth is reached
# minimum number of sample in a node  is too small information game is very low

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("covid_toy - covid_toy.csv")

# %%
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer()

# %%
df["fever"]=si.fit_transform(df[["fever"]])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df["gender"]=lb.fit_transform(df["gender"])
df["cough"]=lb.fit_transform(df["cough"])
df["city"]=lb.fit_transform(df["city"])
df["has_covid"]=lb.fit_transform(df["has_covid"])

# %%
df.head()
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     2          0
# 1   27       1  100.0      0     1          1
# 2   42       1  101.0      0     1          0
# 3   31       0   98.0      0     2          0
# 4   65       0  101.0      0     3          0

# %%
x=df.drop(columns=["has_covid"])
y=df["has_covid"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from  sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)

# %%
from  sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.45

# %%
https://github.com/1602saurab/dt-model-pro

# %%
df=pd.read_csv("titanic - titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df=df.drop(columns=["Name","PassengerId","Ticket","Cabin"])

# %%
df.head()
# Out:
#     Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 12         1       1  female  23.0      1      0   82.2667        S
# 14         1       1  female  47.0      1      0   61.1750        S
# 24         1       1  female  48.0      1      3  262.3750        C
# 26         1       1  female  22.0      0      1   61.9792        C
# 28         0       1    male  41.0      0      0   30.5000        S

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df["Embarked"]=lb.fit_transform(df["Embarked"])

df["Sex"]=lb.fit_transform(df["Sex"])

# %%
# https://github.com/1602saurab/dt-model-pro

# %%
x=df.drop(columns=["Survived"])
y=df['Survived']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
# Now we compute probabilities of features given the class.

# For class = Yes:

# Age = Middle →
# 1
# 3
# 3
# 1
# 	​


# Age = Old →
# 2
# 3
# 3
# 2
# 	​


# Income = High →
# 1
# 3
# 3
# 1
# 	​


# Income = Medium →
# 1
# 3
# 3
# 1
# 	​


# Income = Low →
# 1
# 3
# 3
# 1
# 	​


# For class = No:

# Age = Young →
# 2
# 3
# 3
# 2
# 	​


# Age = Middle →
# 1
# 3
# 3
# 1
# 	​


# Age = Old →
# 0
# 3
# =
# 0
# 3
# 0
# 	​

# =0

# Income = High →
# 1
# 3
# 3
# 1
# 	​


# Income = Medium →
# 1
# 3
# 3
# 1
# 	​


# Income = Low →
# 1
# 3
# 3
# 1
# 	​


# 🔹 Step 3: Prediction Example

# Now suppose we want to predict for a new person:

# %%
# | Person | Age    | Income | BuysComputer |
# | ------ | ------ | ------ | ------------ |
# | 1      | Young  | High   | No           |
# | 2      | Young  | Medium | No           |
# | 3      | Middle | High   | Yes          |
# | 4      | Old    | Medium | Yes          |
# | 5      | Old    | Low    | Yes          |
# | 6      | Middle | Low    | No           |

# %%
# total  = 6
# p(y)  = 3/6 = 0.5
# p(n) = 3/6  = 0.5

# %%
# p(Age = Old , Income = Medium) ---??????

# %%
# Age(young . old , middle)
# Income(Low , Medium , High)

# %%
# case-1
# class = yes
# 3      | Middle | High   | Yes
# | 4      | Old    | Medium | Yes
# | 5      | Old    | Low    | Yes

# %%
# p(Middle/yes)  = 1/3
# p(old/yes) = 2/3
# p(young) = 0

# p(low/yes) = 1/3
# p(middle/yes) = 1/3
# p(high/yes) = 1/3

# %%
# step-2
# class = No

# 1      | Young  | High   | No
# | 2      | Young  | Medium | No
#  6      | Middle | Low    | No

# %%
# p(young/no) = 2/3
# p(middle/no) = 1/3
# p(old/no) = 0

# p(high/no) = 1/3
# p(medium/no) = 1/3
# p(low/no) = 1/3

# %%
# Now we have to test this :
# p(Age = Old , Income = Medium)

# p(Age(old,Medium)/p(yes)) = p(yes)*p(old/yes) * p(medium/yes)
# p(Age(old,Medium)/p(no)) = p(no)*p(old/no) * p(medium/no)

# %%
# p(yes/old,medium) > p(no/old , medimu) --> final output ---> yes
# p(yes/old, medimu) < p(no/old, medium)  ---> final output ---> no

# %%
+#Q1.---> what is difference between clissisication and regression.
#Q2.---> what are fearures and lables in ml.
#Q3.---> what is over fitting and how can it be prevented.
#Q4.---> what is under fitting .
#Q5.---> what is the purpose of model evaluation matrix.
#Q6.---> difference between regression and classification performation evaluation matrix.
#Q7.---> what is cross validation and why it is important.
#Q8.---> what is the role of hyper parameter in supervised ml models.
#Q9.---> what is bias varias trade off.
#Q10.---> how does linear regression work what are the assumptions of linear regression.
#Q11.---> what is multi colinerity and how do you detect it
#Q12.---> how does logistic regression different from linear regression
#Q13.---> how does knn algorithm work and what are the prons and corns of knn
#Q14.---> what is support vector machine and how does it work. what are kernels in svm
#Q15.---> how do you select an appropriate  supervised ml algorithm for a given problem.
#Q16.---> how do you handel categorical and missing data before training a supervised model
#Q17.---> how do you deal with imbalance data . what is smote and when should it be used.
#Q18.---> what is feature selection and what are the different methods to perfom it
#Q19.---> what is ruc and auc curve for clasificarion data.

# %%
# Random Forest Model ----> This is an ensemble method of decision tree .
# when target  data is:
# Numerical ---> RandomForestRegressor--> 100 d.t. --> Average --> prediction
# Cateogircal ---> RandomForestClassifier  --> 100 d.t. ---> 70 yes , 30 no --> final outpt --> yes

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("insurance - insurance.csv")
df.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
df = pd.get_dummies(df , columns = ['sex' , 'smoker' , 'region'])

# %%
df = df.astype(int)
df.head(2)
# Out:
#    age  bmi  children  charges  sex_female  sex_male  smoker_no  smoker_yes  \
# 0   19   27         0    16884           1         0          0           1
# 1   18   33         1     1725           0         1          1           0
#
#    region_northeast  region_northwest  region_southeast  region_southwest
# 0                 0                 0                 0                 1
# 1                 0                 0                 1                 0

# %%
x = df.drop(columns = ['charges'])
y = df['charges']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(x_train , y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rf.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test , y_pred)
# Out:
# 0.8551979974166106

# %%
# When data is categorical

# %%
df = pd.read_csv("covid_toy - covid_toy.csv")
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer()

# %%
df['fever'] = si.fit_transform(df[['fever']])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=  LabelEncoder()

# %%
df['gender'] = lb.fit_transform(df['gender'])
df['cough'] = lb.fit_transform(df['cough'])
df['city'] = lb.fit_transform(df['city'])
df['has_covid'] = lb.fit_transform(df['has_covid'])

# %%
x = df.drop(columns = ['has_covid'])
y = df['has_covid']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2 , random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(x_train ,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.6

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.6

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators': [10 , 50 , 100, 200],
    'max_depth': [None, 10, 20,30],
    'min_samples_split': [1,2, 5,6],
    'min_samples_leaf': [1, 2,4],
    'bootstrap': [True, False]
}

grid_search = GridSearchCV(RandomForestClassifier(), param_grid=param_grid, cv=3)
grid_search.fit(x_train, y_train)

# %%
print("Best Parameters:", grid_search.best_params_)
print("Best Estimator:", grid_search.best_estimator_)

# %%
y_pred_new = grid_search.predict(x_test)

# %%
accuracy_score(y_test , y_pred_new)

# %%
df['has_covid'].value_counts()

# %%
df  = pd.read_csv("titanic - titanic.csv")
df.head(2)

# %%
df = df.dropna()

# %%
df = df.drop(columns = ['Name' , 'Ticket' , 'Cabin' , 'Embarked' , 'Sex'])

# %%
x = df.drop(columns = ['Survived'])
y = df['Survived']

# %%
df['Survived'].value_counts()

# %%
# Imbalance ---> balacne (smote , oversampling,  undersampling)
# What is difference between RandomizedSearchCV and GridSearchCV ?
# What do you mean by imbalanced data in ml ?  balance (smote , oversampling,  undersampling)
# Implement on titanic data .

# %%
from imblearn.over_sampling import SMOTE

smote=SMOTE(sampling_strategy='minority')
x,y=smote.fit_resample(x,y)
y.value_counts()

# %%
df = pd.read_csv("userbehaviour - userbehaviour.csv")

# %%
df.head(2)
# Out:
#    userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0    1001                   17                         634            1
# 1    1002                    0                          54            0
#
#    Ratings  New Password Request  Last Visited Minutes       Status
# 0        9                     7                  2990    Installed
# 1        4                     8                 24008  Uninstalled

# %%
df['Status'] = df['Status'].map({"Installed":0 , "Uninstalled":1})

# %%
df.head(2)
# Out:
#    userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0    1001                   17                         634            1
# 1    1002                    0                          54            0
#
#    Ratings  New Password Request  Last Visited Minutes  Status
# 0        9                     7                  2990       0
# 1        4                     8                 24008       1

# %%
df['Status'].value_counts()
# Out:
# Status
# 0    916
# 1     83
# Name: count, dtype: int64

# %%
x = df.drop(columns = ['Status'])
y = df['Status']

# %%
# !pip install imbalanced-learn
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imblearn.over_sampling import SMOTE

smote=SMOTE(sampling_strategy='minority')
x,y=smote.fit_resample(x,y)
y.value_counts()
# Out:
# Status
# 0    916
# 1    916
# Name: count, dtype: int64
